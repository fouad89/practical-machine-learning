# %%
# mounting google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# opening csv file using numpy 
import numpy as np

# %%
FILE_PATH = '/content/gdrive/MyDrive/AI Masters/Term 1/Practical ML/small_mnist/small_mnist.csv'
data = np.genfromtxt(FILE_PATH, delimiter=",", skip_header=1)

# %%
data.shape
# Out:
# (10000, 785)

# %%
# feature data from col1: ...
data_features = data[:, 1:]
print(data_features.shape)
# Out:
# (10000, 784)

# %%
# normalize pixels by diving by 255.0
data_features = data_features / 255.0
